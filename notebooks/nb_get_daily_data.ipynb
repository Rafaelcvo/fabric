# %%
import requests
import pandas as pd
from datetime import timedelta
# Out:
# StatementMeta(, 48440968-2e2d-4ff4-bb53-ba0a0ad80d0f, 50, Finished, Available, Finished, False)

# %%
# Base URL for GitHub raw CSV files
base_url = 'https://raw.githubusercontent.com/mikailaltundas/datasets-for-training/refs/heads/main/wind-power-dataset/'

# Path to the wind_power table in the Bronze Lakehouse
bronze_table_path ='abfss://CursoUdemy@onelake.dfs.fabric.microsoft.com/LH_Wind_Power_Bronze.Lakehouse/Tables/dbo/wind_power'
# Out:
# StatementMeta(, 48440968-2e2d-4ff4-bb53-ba0a0ad80d0f, 51, Finished, Available, Finished, False)

# %%
# Load existing wind_power data and convert to Pandas
df_spark = spark.read.format('delta').load(bronze_table_path)
df_pandas = df_spark.toPandas()
# Out:
# StatementMeta(, 48440968-2e2d-4ff4-bb53-ba0a0ad80d0f, 52, Finished, Available, Finished, False)

# %%
# Find the most recent date and calculate next day's date
most_recent_date = pd.to_datetime(df_pandas['date'], format = '%Y%m%d').max()
next_date = (most_recent_date + timedelta(days=1)).strftime('%Y%m%d')
# Out:
# StatementMeta(, 48440968-2e2d-4ff4-bb53-ba0a0ad80d0f, 53, Finished, Available, Finished, False)

# %%
# Download and load new data in a Pandas Dataframe
file_url = f'{base_url}{next_date}_wind_power_data.csv'
df_pandas_new = pd.read_csv(file_url)
df_pandas_new['date'] = pd.to_datetime(df_pandas_new['date'])
# Out:
# StatementMeta(, 48440968-2e2d-4ff4-bb53-ba0a0ad80d0f, 44, Finished, Available, Finished, False)

# %%
# Convert to spark dataframe and append in wind_power table
df_spark_new = spark.createDataFrame(df_pandas_new, schema = df_spark.schema)
df_spark_new.write.format('delta').mode('append').save(bronze_table_path)
# Out:
# StatementMeta(, 48440968-2e2d-4ff4-bb53-ba0a0ad80d0f, 49, Finished, Available, Finished, False)
